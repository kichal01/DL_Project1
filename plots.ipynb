

# %%
import numpy as np
import matplotlib.pyplot as plt

# Średnia dla 3 powtórzeń (wymiar 0), dla 3. metryki (indeks 2)
mean_metric = res1[:, 2, :, :].mean(axis=0)  # (3, 20)

# Wykres
epochs = np.arange(1, 21)  # Zakres epok (1-20)
model_labels = ['0.001', '0.0005', '0.0001']

plt.figure(figsize=(10, 6))
for i in range(3):  # Dla każdego modelu
    plt.plot(epochs, mean_metric[i], label=model_labels[i], marker='o')

plt.xlabel("Epoch")
plt.ylabel("Validation loss")
plt.title("Avarage validation loss on 3 tests for different learning rates for efficientnet_b0 model")
plt.legend()
plt.grid(True)
plt.savefig('LearningRate valLoss')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Średnia dla 3 powtórzeń (wymiar 0), dla 3. metryki (indeks 2)
mean_metric = res1[:, 3, :, :].mean(axis=0)  # (3, 20)

# Wykres
epochs = np.arange(1, 21)  # Zakres epok (1-20)
model_labels = ['0.001', '0.0005', '0.0001']

plt.figure(figsize=(10, 6))
for i in range(3):  # Dla każdego modelu
    plt.plot(epochs, mean_metric[i], label=model_labels[i], marker='o')

plt.xlabel("Epoch")
plt.ylabel("Accuracies")
plt.title("Avarage accuracy on 3 tests for different learning rates for efficientnet_b0 model")
plt.legend()
plt.grid(True)
plt.savefig('LearningRate valAccuracy')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Średnia dla 3 powtórzeń (wymiar 0), dla 3. metryki (indeks 2)
mean_metric = res1[:, 0, :, :].mean(axis=0)  # (3, 20)

# Wykres
epochs = np.arange(1, 21)  # Zakres epok (1-20)
model_labels = ['0.001', '0.0005', '0.0001']

plt.figure(figsize=(10, 6))
for i in range(3):  # Dla każdego modelu
    plt.plot(epochs, mean_metric[i], label=model_labels[i], marker='o')

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Avarage training loss on 3 tests for different learning rates for efficientnet_b0 model")
plt.legend()
plt.grid(True)
plt.savefig('LearningRate trainLoss')

plt.show()

# %%
res2 = np.array([([[1.896396836435253,
    1.5984010344201869,
    1.4446623218669132,
    1.3392044288868254,
    1.2502555649896914,
    1.2846737410873175,
    1.1660954192788764,
    1.1227205916392533,
    1.0765761206434532,
    1.0802768372337928,
    1.0993167562410235,
    1.0523471283641728],
   [1.9238745688714765,
    1.6820514527234165,
    1.5477627685124224,
    1.4813589987091043,
    1.3950765215876428,
    1.3410301272842018,
    1.3012588913129135,
    1.2587992758913473,
    1.2426702307367867,
    1.2116063188084147,
    1.2295753918588161,
    1.3419679532843558],
   [1.9199579969387164,
    1.6549083534628153,
    1.5299168178303675,
    1.4252659233117646,
    1.3347575095566837,
    1.2686531329527497,
    1.2098984511738473,
    1.159646605141461,
    1.1191140156747266,
    1.098160932348533,
    1.0716156600551172,
    1.0283333324742587],
   [2.0197226880964907,
    1.740501982075247,
    1.549730440771038,
    1.4311655541373924,
    1.359321067956361,
    1.3115000006827442,
    1.2450623337856748,
    1.202048703350804,
    1.1671822588382796,
    1.0941943782805041,
    [33.93, 32.91, 40.40, 46.07, 48.78, 47.12, 51.89, 54.32, 55.74, 51.41, 56.85, 51.68],
    [33.63, 41.60, 44.22, 47.44, 50.31, 51.82, 51.56, 55.05, 56.46, 56.44, 58.33, 58.60],
    [34.53, 38.07, 43.63, 46.30, 49.81, 51.40, 52.49, 50.82, 53.88, 54.88, 56.93, 54.41]
]

# Tworzenie tablicy NumPy
average_loss = np.array(average_loss).reshape((1, 1, 7, 12))
validation_loss = np.array(validation_loss).reshape((1, 1, 7, 12))
accuracy = np.array(accuracy).reshape((1, 1, 7, 12))

# Metryka "druga" to same zera
zeros = np.zeros((1, 1, 7, 12))

# Konstruowanie końcowej tablicy o shape (1, 4, 7, 12)
res2_3rdepoch = np.concatenate([average_loss, zeros, validation_loss, accuracy], axis=1)

res2_3rdepoch.shape
# Out:
# (1, 4, 7, 12)

# %%
res2_3rdepoch
# Out:
# array([[[[ 1.9031,  1.6057,  1.4656,  1.3573,  1.2677,  1.1972,
#            1.1553,  1.0986,  1.0419,  1.0016,  0.9697,  1.0769],
#          [ 1.9593,  1.6806,  1.5513,  1.4871,  1.4064,  1.3715,
#            1.3163,  1.2996,  1.3143,  1.2282,  1.2068,  1.2186],
#          [ 1.9356,  1.6469,  1.517 ,  1.4251,  1.3449,  1.2865,
#            1.2462,  1.2332,  1.1766,  1.2038,  1.1602,  1.1308],
#          [ 1.978 ,  1.6747,  1.5256,  1.4109,  1.3288,  1.2829,
#            1.2306,  1.2008,  1.1321,  1.4179,  1.1524,  1.089 ],
#          [ 1.9494,  1.6745,  1.7004,  1.5635,  1.4781,  1.4274,
#            1.3842,  1.3284,  1.3148,  1.3082,  1.2644,  1.2297],
#          [ 1.9416,  1.7078,  1.6255,  1.536 ,  1.4632,  1.4102,
#            1.3791,  1.3407,  1.291 ,  1.2657,  1.2427,  1.211 ],
#          [ 1.9372,  1.6955,  1.599 ,  1.5286,  1.4572,  1.4031,
#            1.374 ,  1.3904,  1.3404,  1.3668,  1.2867,  1.2634]],
#
#         [[ 0.    ,  0.    ,  0.    ,  0.    ,  0.    ,  0.    ,
# ...

# %%
res2.shape
#losses_tr, accuracies_tr, losses_val, accuracies_val
# Out:
# (2, 4, 7, 12)

# %%
res2[0]
# Out:
# array([[[ 1.89639684,  1.59840103,  1.44466232,  1.33920443,
#           1.25025556,  1.28467374,  1.16609542,  1.12272059,
#           1.07657612,  1.08027684,  1.09931676,  1.05234713],
#         [ 1.92387457,  1.68205145,  1.54776277,  1.481359  ,
#           1.39507652,  1.34103013,  1.30125889,  1.25879928,
#           1.24267023,  1.21160632,  1.22957539,  1.34196795],
#         [ 1.919958  ,  1.65490835,  1.52991682,  1.42526592,
#           1.33475751,  1.26865313,  1.20989845,  1.15964661,
#           1.11911402,  1.09816093,  1.07161566,  1.02833333],
#         [ 2.01972269,  1.74050198,  1.54973044,  1.43116555,
#           1.35932107,  1.3115    ,  1.24506233,  1.2020487 ,
#           1.16718226,  1.09419438,  1.06450417,  1.02440805],
#         [ 1.93761539,  1.69843866,  1.54500008,  1.48284773,
#           1.38838243,  1.3625218 ,  1.31239523,  1.26685397,
#           1.31118902,  1.26770317,  1.18011621,  1.14960581],
# ...

# %%
res2 = np.concatenate((res2,res2_3rdepoch), axis=0)
res2.shape
# Out:
# (3, 4, 7, 12)

# %%
#CUTMIX
# Dane wejściowe: listy metryk z każdej epoki dla trzech przebiegów (runów)
average_loss_run1 = [2.0267, 1.8358, 1.7458, 1.6756, 1.6202, 1.5697, 1.5275, 1.4866, 1.4722, 1.4434, 1.4030, 1.3615]
validation_loss_run1 = [1.5374, 1.4607, 1.4232, 1.2913, 1.2129, 1.2280, 1.2731, 1.0176, 1.0155, 1.0227, 1.0921, 0.9193]
accuracy_run1 = [43.82, 47.03, 49.13, 54.35, 57.67, 57.07, 56.13, 67.69, 65.50, 65.17, 64.78, 70.32]

average_loss_run2 = [2.0278, 1.8123, 1.7465, 1.6809, 1.6285, 1.5816, 1.5428, 1.5069, 1.4564, 1.4365, 1.4282, 1.3808]
validation_loss_run2 = [1.5078, 1.4522, 1.4152, 1.3291, 1.2888, 1.1555, 1.1722, 1.0505, 1.0139, 0.9594, 1.2160, 0.9662]
accuracy_run2 = [44.15, 47.42, 48.89, 53.08, 55.39, 60.67, 60.61, 65.09, 65.96, 68.20, 60.14, 69.28]

average_loss_run3 = [2.0302, 1.8236, 1.7313, 1.6665, 1.6125, 1.5745, 1.5192, 1.4676, 1.4625, 1.4335, 1.4040, 1.3714]
validation_loss_run3 = [1.5632, 1.3999, 1.3536, 1.4241, 1.2089, 1.1305, 1.1269, 1.0290, 1.2008, 1.0395, 0.9513, 1.0042]
accuracy_run3 = [42.68, 50.67, 51.12, 49.42, 58.51, 61.40, 61.12, 64.86, 58.38, 65.18, 68.73, 67.27]

# Tworzenie tablicy (3, 4, 1, 12)
cutmix = np.zeros((3, 4, 1, 12))

# Uzupełnianie danych dla każdego runu
cutmix[0, 0, 0, :] = average_loss_run1
cutmix[0, 1, 0, :] = np.zeros(12)  # Druga metryka to same zera
cutmix[0, 2, 0, :] = validation_loss_run1
cutmix[0, 3, 0, :] = accuracy_run1

cutmix[1, 0, 0, :] = average_loss_run2
cutmix[1, 1, 0, :] = np.zeros(12)  # Druga metryka to same zera
cutmix[1, 2, 0, :] = validation_loss_run2
cutmix[1, 3, 0, :] = accuracy_run2

cutmix[2, 0, 0, :] = average_loss_run3
cutmix[2, 1, 0, :] = np.zeros(12)  # Druga metryka to same zera
cutmix[2, 2, 0, :] = validation_loss_run3
cutmix[2, 3, 0, :] = accuracy_run3

cutmix.shape
# Out:
# (3, 4, 1, 12)

# %%
final_dataaugmentation = np.concatenate((res2,cutmix), axis=2)
final_dataaugmentation.shape
# Out:
# (3, 4, 8, 12)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Średnia dla 2 prób (wymiar 0), dla 3. metryki (indeks 2)
mean_metric = final_dataaugmentation[:, 2, :, :].mean(axis=0)  # Shape (7, 12)

# Wykres
epochs = np.arange(1, 13)  # Zakres epok (1-12)
model_labels =  ['transform_default',
                  'transform_rotations',
                  'transform_scaling',
                  'transform_greyscale',
                  'transform_random_40',
                  'transform_random_80',
                  'transform_scaling_rotating',
                'CutMix']  # Automatyczne etykiety modeli

plt.figure(figsize=(10, 6))
for i in range(8):  # Dla każdego modelu
    plt.plot(epochs, mean_metric[i], label=model_labels[i], marker='o')

plt.xlabel("Epoch")
plt.ylabel("Average validation loss")
plt.title("Avarage validation loss on 3 tests for different data augmentations for efficientnet_b0 model")
plt.legend()
plt.grid(True)
plt.savefig('Data Augmentation val loss line')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

model_labels =  ['transform_default',
                  'transform_rotations',
                  'transform_scaling',
                  'transform_greyscale',
                  'transform_random_40',
                  'transform_random_80',
                  'transform_scaling_rotating',
                    'CutMix']
# Przyjmujemy, że res2 ma shape (2, 4, 7, 12)
# Wybieramy 3-cią metrykę (indeks 2)
metric_valloss = final_dataaugmentation[:, 2, :, :]

# Finalne wartości (ostatnia epoka)
final_values = metric_valloss[:, :, -1]  # shape (2, 7)

# Minimalne wartości w każdej próbce
min_values = np.min(metric_valloss, axis=-1)  # shape (2, 7)

# Tworzenie wykresu boxplot dla każdego modelu
plt.figure(figsize=(20, 10))
box1 = plt.boxplot([min_values[:, i] for i in range(8)], positions=np.arange(8) - 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="lightblue"), labels=[f"Model {i+1}" for i in range(8)])
box2 = plt.boxplot([final_values[:, i] for i in range(8)], positions=np.arange(8) + 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="g"))

plt.title("Distribution of Final and Min Values of validation loss for Each Model")
plt.ylabel("Loss")
plt.xlabel("Model")
plt.xticks(range(8), [f"{model_labels[i]}" for i in range(8)])
legend_elements = [plt.Line2D([0], [0], color='lightblue', lw=4, label='Min Values'),
                   plt.Line2D([0], [0], color='g', lw=4, label='Final Values')]
plt.legend(handles=legend_elements, loc="upper right")
plt.grid(True)
plt.savefig('Data Augmentation val loss')

plt.show()
# Out:
# C:\Users\danci\AppData\Local\Temp\ipykernel_17652\2056205813.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box1 = plt.boxplot([min_values[:, i] for i in range(8)], positions=np.arange(8) - 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="lightblue"), labels=[f"Model {i+1}" for i in range(8)])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Średnia dla 2 prób (wymiar 0), dla 3. metryki (indeks 2)
mean_metric = final_dataaugmentation[:, 3, :, :].mean(axis=0)  # Shape (7, 12)

# Wykres
epochs = np.arange(1, 13)  # Zakres epok (1-12)
model_labels =  ['transform_default',
                  'transform_rotations',
                  'transform_scaling',
                  'transform_greyscale',
                  'transform_random_40',
                  'transform_random_80',
                  'transform_scaling_rotating',
                'CutMix']  # Automatyczne etykiety modeli

plt.figure(figsize=(10, 6))
for i in range(8):  # Dla każdego modelu
    plt.plot(epochs, mean_metric[i], label=model_labels[i], marker='o')

plt.xlabel("Epoch")
plt.ylabel("Average validation accuracy")
plt.title("Avarage accuracies on 3 tests for different data augmentations for efficientnet_b0 model")
plt.legend()
plt.grid(True)
plt.savefig('Data Augmentation val accuracy line')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

model_labels =  ['transform_default',
                  'transform_rotations',
                  'transform_scaling',
                  'transform_greyscale',
                  'transform_random_40',
                  'transform_random_80',
                  'transform_scaling_rotating',
                    'CutMix']
# Przyjmujemy, że res2 ma shape (2, 4, 7, 12)
metric_valloss = final_dataaugmentation[:, 3, :, :]

# Finalne wartości (ostatnia epoka)
final_values = metric_valloss[:, :, -1]  # shape (2, 7)

max_values = np.max(metric_valloss, axis=-1)  # shape (2, 7)

# Tworzenie wykresu boxplot dla każdego modelu
plt.figure(figsize=(20, 10))
box1 = plt.boxplot([max_values[:, i] for i in range(8)], positions=np.arange(8) - 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="lightblue"), labels=[f"Model {i+1}" for i in range(8)])
box2 = plt.boxplot([final_values[:, i] for i in range(8)], positions=np.arange(8) + 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="g"))

plt.title("Distribution of Final and Max Values of accuracy for Each Model")
plt.ylabel("Accuracy")
plt.xlabel("Model")
plt.xticks(range(8), [f"{model_labels[i]}" for i in range(8)])
legend_elements = [plt.Line2D([0], [0], color='lightblue', lw=4, label='Max Values'),
                   plt.Line2D([0], [0], color='g', lw=4, label='Final Values')]
plt.legend(handles=legend_elements, loc="lower right")
plt.grid(True)
plt.savefig('Data Augmentation val accuracy')
plt.show()
# Out:
# C:\Users\danci\AppData\Local\Temp\ipykernel_17652\1845181090.py:22: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box1 = plt.boxplot([max_values[:, i] for i in range(8)], positions=np.arange(8) - 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="lightblue"), labels=[f"Model {i+1}" for i in range(8)])

# %%
max_values
# Out:
# array([[59.64888889, 59.33888889, 63.18444444, 57.73      , 61.15555556,
#         59.20444444, 58.28111111, 70.32      ],
#        [61.06      , 56.35      , 61.08111111, 58.75555556, 60.99      ,
#         57.60888889, 57.97666667, 69.28      ],
#        [60.68      , 58.9       , 60.77      , 57.91      , 56.85      ,
#         58.6       , 56.93      , 68.73      ]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Średnia dla 2 prób (wymiar 0), dla 3. metryki (indeks 2)
mean_metric = final_dataaugmentation[:, 0, :, :].mean(axis=0)  # Shape (7, 12)

# Wykres
epochs = np.arange(1, 13)  # Zakres epok (1-12)
model_labels =  ['transform_default',
                  'transform_rotations',
                  'transform_scaling',
                  'transform_greyscale',
                  'transform_random_40',
                  'transform_random_80',
                  'transform_scaling_rotating',
                'CutMix']  # Automatyczne etykiety modeli

plt.figure(figsize=(10, 6))
for i in range(8):  # Dla każdego modelu
    plt.plot(epochs, mean_metric[i], label=model_labels[i], marker='o')

plt.xlabel("Epoch")
plt.ylabel("Average train loss")
plt.title("Avarage train loss on 3 tests for different data augmentations for efficientnet_b0 model")
plt.legend()
plt.grid(True)
plt.savefig('Data Augmentation train loss line')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

model_labels =  ['transform_default',
                  'transform_rotations',
                  'transform_scaling',
                  'transform_greyscale',
                  'transform_random_40',
                  'transform_random_80',
                  'transform_scaling_rotating',
                    'CutMix']
# Przyjmujemy, że res2 ma shape (2, 4, 7, 12)
metric_valloss = final_dataaugmentation[:, 0, :, :]

# Finalne wartości (ostatnia epoka)
final_values = metric_valloss[:, :, -1]  # shape (2, 7)

min_values = np.min(metric_valloss, axis=-1)  # shape (2, 7)

# Tworzenie wykresu boxplot dla każdego modelu
plt.figure(figsize=(20, 10))
box1 = plt.boxplot([min_values[:, i] for i in range(8)], positions=np.arange(8) - 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="lightblue"), labels=[f"Model {i+1}" for i in range(8)])
box2 = plt.boxplot([final_values[:, i] for i in range(8)], positions=np.arange(8) + 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="g"))

plt.title("Distribution of Final and Min Values of  train loss for Each Model")
plt.ylabel("loss")
plt.xlabel("Model")
plt.xticks(range(8), [f"{model_labels[i]}" for i in range(8)])
legend_elements = [plt.Line2D([0], [0], color='lightblue', lw=4, label='Max Values'),
                   plt.Line2D([0], [0], color='g', lw=4, label='Final Values')]
plt.legend(handles=legend_elements, loc="lower right")
plt.grid(True)
plt.savefig('Data Augmentation train loss')
plt.show()
# Out:
# C:\Users\danci\AppData\Local\Temp\ipykernel_17652\1064518731.py:22: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box1 = plt.boxplot([min_values[:, i] for i in range(8)], positions=np.arange(8) - 0.2, widths=0.3, patch_artist=True, boxprops=dict(facecolor="lightblue"), labels=[f"Model {i+1}" for i in range(8)])

# %%
#custom cnn, cutmix

res3_1 = np.array([[1.6784299084118435,
   1.5940250354153769,
   1.530903683389936,
   1.4815372722489493,
   1.4076869479247502,
   1.35075124672481,
   1.34758323601314,
   1.3786517117704664,
   1.3139239404882703,
   1.2910399300711495,
   1.315556012732642,
   1.2550739169120788,
   1.2481779562575477,
   1.283465439081192,
   1.252739006280899,
   1.2303933722632272,
   1.2628968570913588,
   1.2486748473984854,
   1.2489891179970332,
   1.2356467034135545,
   1.2279863161700113,
   1.2088507494756153,
   1.2530273846217563,
   1.230258703657559,
   1.2209163819040572,
   1.2069915499005999,
   1.1900899478367397,
   1.1709749894482748,
   1.2206744853939329,
   1.1800000705889293,
   1.2030402941363199,
   1.2142126057829177,
   1.137358991588865,
   1.1653943393911634,
   1.1578595293419702,
   1.1737725675106048,
   1.1962518061910357,
   1.178653295976775,
   1.2146175018378667,
   1.1696138939687184,
   1.173088492665972,
   1.1548610840524947,
   1.1627670641456331,
   1.1389067769050598,
   1.1498574163232531,
   1.1601302014929908,
   1.1475720307656696,
   1.1507425010204315,
   1.1514648258686067,
   1.1554490532193864,
   1.1641494346516472],
  [39.073660714285715,
   42.042410714285715,
   44.453125,
   46.127232142857146,
   51.61830357142857,
   53.113839285714285,
   53.504464285714285,
   52.332589285714285,
   53.63839285714286,
   55.30133928571429,
   54.698660714285715,
   57.265625,
   57.265625,
   55.63616071428571,
   56.14955357142857,
   57.845982142857146,
   55.56919642857143,
   57.36607142857143,
   58.002232142857146,
   58.013392857142854,
   58.839285714285715,
   57.723214285714285,
   57.09821428571429,
   58.02455357142857,
   57.511160714285715,
   59.25223214285714,
   58.77232142857143,
   59.799107142857146,
   57.54464285714286,
   60.36830357142857,
   58.783482142857146,
   58.783482142857146,
   60.32366071428571,
   59.93303571428571,
   60.747767857142854,
   60.22321428571429,
   59.073660714285715,
   59.955357142857146,
   58.058035714285715,
   60.011160714285715,
   60.32366071428571,
   60.691964285714285,
   60.401785714285715,
   61.138392857142854,
   60.558035714285715,
   60.011160714285715,
   60.04464285714286,
   60.82589285714286,
   61.294642857142854,
   61.361607142857146,
   59.39732142857142],
  [2.0561935491568666,
   1.9551485443928602,
   1.9065383063535277,
   1.8730688117968757,
   1.8421103340052678,
   1.8216538369952149,
   54.85491071428571,
   54.497767857142854,
   54.07366071428571,
   54.64285714285714,
   55.044642857142854,
   54.308035714285715,
   54.31919642857142,
   54.01785714285714,
   56.261160714285715,
   54.12946428571429,
   55.558035714285715,
   56.339285714285715,
   55.613839285714285,
   56.841517857142854,
   57.35491071428571,
   56.97544642857143],
  [2.1578973735912355,
   2.0623583924965225,
   2.0288375239890777,
   2.011044432274738,
   1.9936418674817387,
   1.9826991188670187,
   1.969950012137217,
   1.9582956601477042,
   1.9480720223817913,
   1.9416525742646729,
   1.9293862399092445,
   1.91550156048366,
   1.9061926329652723,
   1.9025691424012607,
   1.8906650542365633,
   1.8875863758824611,
   1.8793820973059432,
   1.878110429710247,
   1.8765280347558397,
   1.870568365938882,
   1.859940750597213,
   1.8482519364475611,
   1.848323446177555,
   1.8476275217473803,
   1.8420899529446926,
   1.8380206890282431,
   1.833251219737928,
   1.8293746130298705,
   1.8281979756568796,
   1.8224208698936957,
   1.8174943393566292,
   1.8146960097335294,
   1.808590710459657,
   1.8043263340640254,
   1.8050249926825321,
   1.8038903911993194,
   1.7982136521173353,
   1.7958909388374757,
   1.7977375741875925,
   1.7845945526033575,
   1.7846430029187883,
   1.7844310621886534,
   1.7647140469208793,
   1.7775350634562013,
   1.7720687059790172,
   1.7729287610972444,
   1.773059385417621,
   1.7654609104039911,
   1.7610314044023798,
   1.7610763392299307,
   1.7612811759082494,
   1.7533517379496397,
   1.7591552159933648,
   1.7562877730265865,
   1.749944086268004,
   1.7632418598955883,
   1.7451757330714852,
   1.7564701348564349,
   1.7450208418235427,
   1.743521604371901]])

# %%
res3_2.shape
# Out:
# (3, 60)

# %%
res3_1.shape
# Out:
# (3, 51)

# %%
line1 = res3_1[0, :]
line2 = res3_2[0, :]

# Tworzymy wykres
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(line1) + 1), line1, label='learning rate = 0.001', marker='o')
plt.plot(range(1, len(line2) + 1), line2, label='learning rate = 0.0001', marker='x')
plt.xlabel('Epoch')
plt.ylabel('validation losses')
plt.title('Custom CNN_2_dropout, cutmix validation losses')
plt.savefig('Custom CNN_2_dropout, cutmix validation losses')
plt.legend()
plt.show()

# %%
line1 = res3_1[1, :]
line2 = res3_2[1, :]

# Tworzymy wykres
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(line1) + 1), line1, label='learning rate = 0.001', marker='o')
plt.plot(range(1, len(line2) + 1), line2, label='learning rate = 0.0001', marker='x')
plt.xlabel('Epoch')
plt.ylabel('validation accuracy')
plt.title('Custom CNN_2_dropout, cutmix validation accuracies')
plt.legend()
plt.savefig('Custom CNN_2_dropout, cutmix validation accuracies')
plt.show()

# %%
line1 = res3_1[2, :]
line2 = res3_2[2, :]

# Tworzymy wykres
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(line1) + 1), line1, label='learning rate = 0.001', marker='o')
plt.plot(range(1, len(line2) + 1), line2, label='learning rate = 0.0001', marker='x')
plt.xlabel('Epoch')
plt.ylabel('validation loss')
plt.title('Custom CNN_2_dropout, cutmix train losses')
plt.legend()
plt.savefig('Custom CNN_2_dropout, cutmix train_losses')
plt.show()

# %%
import pandas as pd
val_losses=pd.DataFrame([[1.518992062977382,
   1.4486844965389796,
   1.3462432503700257,
   1.3094680522169386,
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.518992  1.448684  1.346243  1.309468  1.245007  1.213380  1.192211
# 1  1.502067  1.396440  1.307168  1.288359  1.266763  1.234945  1.205676
# 2  1.476616  1.413523  1.361476  1.340084  1.299685  1.359994  1.300620
# 3  1.549362  1.461032  1.313621  1.330524  1.229158  1.202515  1.175508
# 4  1.483587  1.412285  1.367220  1.337350  1.305623  1.354408  1.305814
#
#          7         8         9   ...        39        40       41        42  \
# 0  1.211556  1.187356  1.151482  ...  1.205786  1.255399  1.22928  1.220674
# 1  1.250738  1.185839  1.206386  ...       NaN       NaN      NaN       NaN
# 2  1.377567  1.371589  1.456834  ...       NaN       NaN      NaN       NaN
# 3  1.176433  1.147374  1.141345  ...       NaN       NaN      NaN       NaN
# 4  1.349419  1.364725  1.446767  ...       NaN       NaN      NaN       NaN
#
#          43        44        45        46        47        48
# ...

# %%
plt.figure(figsize=(12, 6))
labels = ['CNN_dropout lr 0.001',
          'CNN_2 lr 0.001',
          'CNN lr 0.001',
        'CNN_2_dropout, lr 0.001',
         'CNN 2nd try, lr 0.001'
         ]
# Rysujemy każdą linię osobno
for i in range(len(val_losses)):
    plt.plot(val_losses.columns, val_losses.iloc[i, :], label=labels[i], marker='o')

plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Each Model')
plt.legend(title='Lines', loc='upper right')
plt.grid(True)

plt.savefig('Validation Loss for Each Model simple cnn')
plt.show()

# %%
val_accuracies = pd.DataFrame([
    [45.078125,
   46.841517857142854,
   50.770089285714285,
   52.44419642857143,
   54.933035714285715,
   55.95982142857143,
   57.25446428571429,
   56.13839285714286,
   57.566964285714285,
   58.38169642857143,
   57.042410714285715,
   58.113839285714285,
   58.41517857142857,
   56.46205357142857,
   57.46651785714286,
   58.72767857142858,
   57.332589285714285,
   59.11830357142858,
   58.113839285714285,
   58.96205357142858,
   59.53125,
   58.783482142857146,
   58.38169642857143,
   58.59375,
   58.32589285714286,
   58.25892857142857,
   59.45312499999999,
   58.59375,
   58.046875,
   58.560267857142854,
   57.74553571428571,
   58.06919642857142,
   57.99107142857143,
   56.830357142857146,
   57.75669642857143,
   58.87276785714286,
   57.34375000000001,
   57.86830357142857,
   57.957589285714285,
   58.13616071428571,
   58.10267857142857,
   57.60044642857143,
   58.560267857142854,
   58.22544642857142,
   58.995535714285715,
   57.52232142857143,
   57.421875,
   57.89062499999999,
   58.404017857142854],[45.078125,
   49.00669642857143,
   52.86830357142858,
   53.20312499999999,
   54.40848214285714,
   55.52455357142857,
   57.14285714285714,
   55.63616071428571,
   57.667410714285715,
   56.50669642857142,
   54.84375,
   57.779017857142854,
   57.10937499999999,
   55.52455357142857,
   54.16294642857142,
   56.68526785714286,
   55.60267857142858,
   56.14955357142857,
   56.46205357142857,
   56.20535714285714,
   56.395089285714285,
   55.79241071428571,
   55.111607142857146,
   55.44642857142858,
   55.02232142857143,
   56.160714285714285,
   55.3125,
   55.92633928571429,
   54.921875,
   54.933035714285715],[46.94196428571429,
   48.16964285714286,
   50.29017857142857,
   51.43973214285714,
   53.49330357142858,
   52.51116071428571,
   54.43080357142858,
   52.79017857142857,
   53.08035714285714,
   51.595982142857146,
   53.214285714285715,
   53.33705357142857,
   52.77901785714286],[42.94642857142857,
   46.09933035714286,
   51.953125,
   50.982142857142854,
   55.35714285714286,
   56.79129464285714,
   57.36607142857143,
   57.527901785714285,
   58.41517857142857,
   59.10714285714286,
   58.33147321428571,
   59.760044642857146,
   59.754464285714285,
   58.21986607142857,
   58.49888392857143,
   60.03906249999999,
   58.950892857142854,
   60.56361607142857,
   60.56361607142857,
   60.86495535714286,
   60.64732142857143,
   60.26785714285714,
   60.91517857142858,
   61.35602678571429,
   60.552455357142854,
   60.440848214285715,
   60.9375,
   60.736607142857146,
   60.76450892857142,
   60.47991071428571,
   60.29017857142858,
   59.994419642857146],[46.38950892857142,
   48.660714285714285,
   50.1953125,
   51.50111607142858,
   53.465401785714285,
   52.61160714285714,
   54.207589285714285,
   53.510044642857146,
   53.24776785714286,
   51.70200892857143,
   53.80580357142857,
   52.684151785714285,
   52.71763392857143,
   52.02008928571429,
   51.73549107142858]
])

# %%
val_accuracies
# Out:
#           0          1          2          3          4          5   \
# 0  45.078125  46.841518  50.770089  52.444196  54.933036  55.959821
# 1  45.078125  49.006696  52.868304  53.203125  54.408482  55.524554
# 2  46.941964  48.169643  50.290179  51.439732  53.493304  52.511161
# 3  42.946429  46.099330  51.953125  50.982143  55.357143  56.791295
# 4  46.389509  48.660714  50.195312  51.501116  53.465402  52.611607
#
#           6          7          8          9   ...         39         40  \
# 0  57.254464  56.138393  57.566964  58.381696  ...  58.136161  58.102679
# 1  57.142857  55.636161  57.667411  56.506696  ...        NaN        NaN
# 2  54.430804  52.790179  53.080357  51.595982  ...        NaN        NaN
# 3  57.366071  57.527902  58.415179  59.107143  ...        NaN        NaN
# 4  54.207589  53.510045  53.247768  51.702009  ...        NaN        NaN
#
#           41         42         43         44         45         46  \
# ...

# %%
plt.figure(figsize=(12, 6))
labels = ['CNN_dropout lr 0.001',
          'CNN_2 lr 0.001',
          'CNN lr 0.001',
        'CNN_2_dropout, lr 0.001',
         'CNN 2nd try, lr 0.001'
         ]
# Rysujemy każdą linię osobno
for i in range(len(val_accuracies)):
    plt.plot(val_accuracies.columns, val_accuracies.iloc[i, :], label=labels[i], marker='o')

plt.xlabel('Epoch')
plt.ylabel('Validation Accuracies')
plt.title('Validation accuracy for Each Model')
plt.legend(title='Lines', loc='lower right')
plt.grid(True)

plt.savefig('Validation Accuracy for Each Model simple cnn')
plt.show()

# %%
train_losses = pd.DataFrame([
    [1.6928961923466392,
   1.473445524030657,
   1.368958224535158,
   1.298225041857491,
   1.2496767505399708,
   1.2130982789403595,
   1.1783092897160306,
   1.155764786842959,
   1.1270583545221196,
   1.107730686749307,
   1.0912135770410702,
   1.072108325080492,
   1.0567885847827094,
   1.0398219789523306,
   1.0285767701897286,
   1.015164560388824,
   1.0052335684657012,
   0.995168689598661,
   0.9858004366495801,
   0.9723254483730639,
   0.9619200823573076,
   0.9531879013704763,
   0.9449166330616781,
   0.9389481891235224,
   0.9323658910344997,
   0.9219201428295453,
   0.919481649327634,
   0.9146163705484869,
   0.9050407560480005,
   0.9003272699648892,
   0.8972665346422853,
   0.8866044175734991,
   0.8825778383774883,
   0.8786184080712915,
   0.877865949165084,
   0.8703786144463322,
   0.869130382109129,
   0.8634999462621129,
   0.8557211320156227,
   0.8505565821700852,
   0.8496190143461845,
   0.8458367515389769,
   0.8440408261218814,
   0.8373886831448955,
   0.8429602545122772,
   0.8340116012748794,
   0.8281657612527104,
   0.8284857250014009,
   0.8287059451428896],[1.676762722194322,
   1.4305611011739647,
   1.3224312359759718,
   1.2508716434981693,
   1.1975443669473693,
   1.157847812350286,
   1.1228664364896095,
   1.0943948312185297,
   1.0670222485836465,
   1.0398741653817887,
   1.019323707304699,
   0.9985510481107125,
   0.9787690112077351,
   0.9612644930299327,
   0.9412616631327237,
   0.926402012380032,
   0.9081481353729942,
   0.8909441073396651,
   0.8769874932415196,
   0.8613874778606914,
   0.8440950584055772,
   0.8309303211166067,
   0.8158810435242914,
   0.8037973592149169,
   0.7862660975725666,
   0.7751916700970135,
   0.7595260069568528,
   0.7489932214824037,
   0.7371386370721572,
   0.722339545083368],[1.6183061592106118,
   1.4108532504486377,
   1.3117267768181378,
   1.227513827367632,
   1.1560013675909984,
   1.0944404703298187,
   1.0356418657319801,
   0.9822263931584172,
   0.9218775599919572,
   0.8703467292656861,
   0.8193651232510996,
   0.7695215453513565,
   0.7187428216859645],[1.733208957426753,
   1.5067539714970484,
   1.4023439241116489,
   1.3263025871810967,
   1.269405670681149,
   1.2270344832558622,
   1.1915141438116144,
   1.1656069040891543,
   1.1413385722344025,
   1.1190033046675643,
   1.1017650415394098,
   1.0892789690055658,
   1.0740364735314587,
   1.0572088980979757,
   1.0484746218405467,
   1.0388018860406882,
   1.0232896906904236,
   1.018432807990144,
   1.0061334278791951,
   0.9999289161021945,
   0.9932238855680507,
   0.9853856214497558,
   0.9773637438040722,
   0.9686789995148068,
   0.9600811169006847,
   0.9618550450478197,
   0.952852647357065,
   0.9496086307171819,
   0.939551985763707,
   0.9384599053952909,
   0.9380993777839699,
   0.9330249200412883],[1.6183061592106118,
   1.4108532504486377,
   1.3117267768181378,
   1.227513827367632,
   1.1560013675909984,
   1.0944404703298187,
   1.0356418657319801,
   0.9822263931584172,
   0.9218775599919572,
   0.8703467292656861,
   0.8193651232510996,
   0.7695215453513565,
   0.7187428216859645,
   0.673729964474371,
   0.6306857458860551]
])

# %%
plt.figure(figsize=(12, 6))
labels = ['CNN_dropout lr 0.001',
          'CNN_2 lr 0.001',
          'CNN lr 0.001',
        'CNN_2_dropout, lr 0.001',
         'CNN 2nd try, lr 0.001'
         ]
# Rysujemy każdą linię osobno
for i in range(len(train_losses)):
    plt.plot(train_losses.columns, train_losses.iloc[i, :], label=labels[i], marker='o')

plt.xlabel('Epoch')
plt.ylabel('Train losses')
plt.title('Train Loss for Each Model')
plt.legend(title='Lines', loc='upper right')
plt.grid(True)

plt.savefig('train_losses for Each Model simple cnn')
plt.show()

# %%
from PIL import Image
from torchvision.datasets import ImageFolder
from torchvision import transforms

transform_rotations_test = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomRotation(degrees = (-50,50), fill = 255)
])
train_set = ImageFolder(root='cinic10/versions/1/train//', transform=transform_rotations_test)
img, label  = train_set[0]
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
transform_rotations_test = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomRotation(degrees = (-50,50))
])
train_set = ImageFolder(root='cinic10/versions/1/train//', transform=transform_rotations_test)
img, label  = train_set[0]
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
